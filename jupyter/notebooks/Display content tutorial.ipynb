# %%
import os, subprocess
from IPython.display import display, IFrame, HTML

# %% [markdown]
# # IPython WILL display local HTML files with rich content in an IFrame. However, the path value of the "src" attribute is relative to the directory within which Jupyter notebook is running

# %%
IFrame(src="simple-test.html", width=500, height=100)
# Out:
#         <iframe
#             width="500"
#             height="100"
#             src="simple-test.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src="composite-test.html", width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="composite-test.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # If a page contains CSS, JavaScript, and HTML, an instance of the IPython HTML class will render it as a long, incomprehensible (base64??) string

# %%
HTML(filename="/Users/austinchang/tutorials/python/jupyter/notebooks/composite-test.html")

# %%
HTML(url="https://docs.docker.com/engine/reference/run/#network-settings")

# %%
HTML(url="https://www.sheldonbrown.com/web_sample1.html")

# %% [markdown]
# # A web page that contains HTML, and ONLY HTML, renders fine with an instance of the HTML class

# %%
HTML(filename="/Users/austinchang/tutorials/python/jupyter/notebooks/simple-test.html")

# %%
HTML(url="https://www.york.ac.uk/teaching/cws/wws/webpage1.html")

# %% [markdown]
# # The IPython IFrame display class works well when I can access a resource through a simple URL. Keep in mind that a localhost URL references the machine running the browser, not the machine running Jupyter notebook

# %%
IFrame(src="https://docs.docker.com/engine/reference/run/#network-settings", width=1000, height=500)

# %%
IFrame(src="http://localhost:8000/test.html", width=300, height=300)

# %%
HTML('<iframe width="560" height="315" src="file:///Users/austinchang/Desktop/test.html" frameborder="0" allowfullscreen></iframe>')
